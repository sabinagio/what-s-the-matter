# %%
import configparser

# For sending GET requests from the API
import requests
# For saving access tokens and for file management when creating and adding to the dataset
import os
# For dealing with json responses we receive from the API
import json
# For displaying the data after
import pandas as pd
# For saving the response data in CSV format
import csv
# For parsing the dates received from twitter in readable formats
import datetime
import dateutil.parser
import unicodedata
#To add wait time between requests
import time

# %%
# setting token variable
config = configparser.RawConfigParser()
config.read('config.ini')
os.environ['TOKEN'] = config['twitter']['bearer_token']


# function to retrieve the token
def auth():
    return os.getenv('TOKEN')


# function to create headers
def create_headers(bearer_token):
    headers = {"Authorization": "Bearer {}".format(bearer_token)}
    return headers


# function to create URL
def create_url(keywords, max_results = 100):
    
    search_url = "https://api.twitter.com/2/tweets/search/recent" #Change to the endpoint you want to collect data from

    #change params based on the endpoint you are using
    query_params = {'query': keywords,
                    #'start_time': start_date,
                    #'end_time': end_date,
                    'max_results': max_results,
                    'expansions': 'author_id,in_reply_to_user_id,geo.place_id',
                    'tweet.fields': 'id,text,author_id,in_reply_to_user_id,geo,context_annotations,conversation_id,created_at,lang,public_metrics,referenced_tweets,reply_settings,source,possibly_sensitive,entities,attachments',
                    'user.fields': 'id,name,username,created_at,description,public_metrics,verified',
                    'place.fields': 'full_name,id,country,country_code,geo,name,place_type',
                    'next_token': {}}
    return (search_url, query_params)


# function to connect to endpoint
def connect_to_endpoint(url, headers, params, next_token = None):
    params['next_token'] = next_token   #params object received from create_url function
    response = requests.request("GET", url, headers = headers, params = params)
    print("Endpoint Response Code: " + str(response.status_code))

    if response.status_code != 200:
        raise Exception(response.status_code, response.text)
        
    return response.json()

# %% [markdown]
# ##### EXPLORING THE DATA WITH A 1ST QUERY

# %%
# FIRST QUERY

# setting the keywords as a variable
keywords = '''terror OR alarm OR panic OR unease OR scare OR afraid of OR careful about \ lang:en'''

# inputs for the request
bearer_token = auth()
headers = create_headers(bearer_token)
keyword = keywords
max_results = 100

# getting and printing the response from the API
url = create_url(keyword, max_results)
print(url)
json_response = connect_to_endpoint(url[0], headers, url[1])
print(json.dumps(json_response, indent=4, sort_keys=True))

# getting the next token
next_token = json_response['meta']['next_token']
# Out:
# ('https://api.twitter.com/2/tweets/search/recent', {'query': 'terror OR alarm OR panic OR unease OR scare OR afraid of OR careful about \\ lang:en', 'max_results': 100, 'expansions': 'author_id,in_reply_to_user_id,geo.place_id', 'tweet.fields': 'id,text,author_id,in_reply_to_user_id,geo,context_annotations,conversation_id,created_at,lang,public_metrics,referenced_tweets,reply_settings,source,possibly_sensitive,entities,attachments', 'user.fields': 'id,name,username,created_at,description,public_metrics,verified', 'place.fields': 'full_name,id,country,country_code,geo,name,place_type', 'next_token': {}})
# Endpoint Response Code: 200
# {
#     "data": [
#         {
#             "attachments": {
#                 "media_keys": [
#                     "3_1563562866556276736"
#                 ]
#             },
#             "author_id": "1555323426784456704",
#             "context_annotations": [
#                 {
#                     "domain": {
#                         "description": "Named people in the world like Nelson Mandela",
#                         "id": "10",
#                         "name": "Person"
#                     },
#                     "entity": {
#                         "description": "45th US President, Donald Trump",
#                         "id": "799022225751871488",
#                         "name": "Donald Trump"
#                     }
#                 },
#                 {
#                     "domain": {
#                         "description": "Named people in the world like Nelson Mandela",
#                         "id": "10",
#                         "name": "Person"
#                     },
#                     "entity": {
#                         "id": "1138106947234779137",
#                         "name": "Jon Cooper"
#                     }
#                 },
#                 {
#                     "domain": {
#                         "description": "Politicians in the world, like Joe Biden",
#                         "id": "35",
#                         "name": "Politician"
#                     },
#                     "entity": {
#                         "description": "45th US President, Donald Trump",
#                         "id": "799022225751871488",
#                         "name": "Donald Trump"
#                     }
#                 },
#                 {
#                     "domain": {
#                         "description": "Politicians in the world, like Joe Biden",
#                         "id": "35",
#                         "name": "Politician"
#                     },
#                     "entity": {
#                         "id": "1138106947234779137",
#                         "name": "Jon Cooper"
#                     }
#                 },
#                 {
#                     "domain": {
#                         "description": "A taxonomy view into the Semantic Core knowledge graph",
#                         "id": "131",
#                         "name": "Unified Twitter Taxonomy"
#                     },
#                     "entity": {
#                         "description": "45th US President, Donald Trump",
#                         "id": "799022225751871488",
#                         "name": "Donald Trump"
#                     }
#                 },
#                 {
#                     "domain": {
#                         "description": "A taxonomy view into the Semantic Core knowledge graph",
#                         "id": "131",
#                         "name": "Unified Twitter Taxonomy"
#                     },
#                     "entity": {
#                         "description": "Politics",
#                         "id": "847878884917886977",
#                         "name": "Politics"
#                     }
#                 },
#                 {
#                     "domain": {
#                         "description": "A taxonomy view into the Semantic Core knowledge graph",
#                         "id": "131",
#                         "name": "Unified Twitter Taxonomy"
#                     },
#                     "entity": {
#                         "description": "Politician",
#                         "id": "1070032753834438656",
#                         "name": "Political figures"
#                     }
#                 },
#                 {
#                     "domain": {
#                         "description": "A taxonomy view into the Semantic Core knowledge graph",
#                         "id": "131",
#                         "name": "Unified Twitter Taxonomy"
#                     },
#                     "entity": {
#                         "id": "1138106947234779137",
#                         "name": "Jon Cooper"
#                     }
#                 }
#             ],
#             "conversation_id": "1562459481031581697",
#             "created_at": "2022-08-27T16:23:44.000Z",
#             "entities": {
#                 "annotations": [
#                     {
#                         "end": 69,
#                         "normalized_text": "Donald Trump",
#                         "probability": 0.9914,
#                         "start": 58,
#                         "type": "Person"
#                     }
#                 ],
#                 "mentions": [
#                     {
#                         "end": 15,
#                         "id": "1298372735383605249",
#                         "start": 0,
#                         "username": "RonFilipkowski"
#                     },
#                     {
#                         "end": 32,
#                         "id": "27493883",
#                         "start": 16,
#                         "username": "joncoopertweets"
#                     }
#                 ],
#                 "urls": [
#                     {
#                         "display_url": "pic.twitter.com/8zHzE3aJ0u",
#                         "end": 181,
#                         "expanded_url": "https://twitter.com/TTj76447322/status/1563562921644343296/photo/1",
#                         "media_key": "3_1563562866556276736",
#                         "start": 158,
#                         "url": "https://t.co/8zHzE3aJ0u"
#                     }
#                 ]
#             },
#             "id": "1563562921644343296",
#             "in_reply_to_user_id": "1298372735383605249",
#             "lang": "en",
#             "possibly_sensitive": false,
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 0
#             },
#             "referenced_tweets": [
#                 {
#                     "id": "1562459481031581697",
#                     "type": "replied_to"
#                 }
#             ],
#             "reply_settings": "everyone",
#             "source": "Twitter Web App",
#             "text": "@RonFilipkowski @joncoopertweets This is Domestic Terror: Donald Trump, the biggest CON MAN in American History. His people bought it hook, line, and sinker. https://t.co/8zHzE3aJ0u"
#         },
#         {
#             "author_id": "1102298694743924737",
#             "conversation_id": "1563562919924678657",
#             "created_at": "2022-08-27T16:23:44.000Z",
#             "entities": {
#                 "annotations": [
#                     {
#                         "end": 34,
#                         "normalized_text": "Lily",
#                         "probability": 0.7255,
#                         "start": 31,
#                         "type": "Person"
#                     }
#                 ],
#                 "mentions": [
#                     {
#                         "end": 16,
#                         "id": "3794031137",
#                         "start": 3,
#                         "username": "ConorGogarty"
#                     }
#                 ]
#             },
#             "id": "1563562919924678657",
#             "lang": "en",
#             "possibly_sensitive": false,
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 244
#             },
#             "referenced_tweets": [
#                 {
#                     "id": "1563131038213505024",
#                     "type": "retweeted"
#                 }
#             ],
#             "reply_settings": "everyone",
#             "source": "Twitter Web App",
#             "text": "RT @ConorGogarty: \u201cThe pain of Lily being taken from her family is unbearable. I am suffering many physical symptoms which are debilitating\u2026"
#         },
#         {
#             "author_id": "961113187453165569",
#             "context_annotations": [
#                 {
#                     "domain": {
#                         "description": "Named people in the world like Nelson Mandela",
#                         "id": "10",
#                         "name": "Person"
#                     },
#                     "entity": {
#                         "description": "US President Joe Biden",
#                         "id": "10040395078",
#                         "name": "Joe Biden"
#                     }
#                 },
#                 {
#                     "domain": {
#                         "description": "Politicians in the world, like Joe Biden",
#                         "id": "35",
#                         "name": "Politician"
#                     },
#                     "entity": {
#                         "description": "US President Joe Biden",
#                         "id": "10040395078",
#                         "name": "Joe Biden"
#                     }
#                 },
#                 {
#                     "domain": {
#                         "description": "A taxonomy view into the Semantic Core knowledge graph",
#                         "id": "131",
#                         "name": "Unified Twitter Taxonomy"
#                     },
#                     "entity": {
#                         "description": "US President Joe Biden",
#                         "id": "10040395078",
#                         "name": "Joe Biden"
#                     }
#                 },
#                 {
#                     "domain": {
#                         "description": "A taxonomy view into the Semantic Core knowledge graph",
#                         "id": "131",
#                         "name": "Unified Twitter Taxonomy"
#                     },
#                     "entity": {
#                         "description": "Politics",
#                         "id": "847878884917886977",
#                         "name": "Politics"
#                     }
#                 },
#                 {
#                     "domain": {
#                         "description": "A taxonomy view into the Semantic Core knowledge graph",
#                         "id": "131",
#                         "name": "Unified Twitter Taxonomy"
#                     },
#                     "entity": {
#                         "description": "Politician",
#                         "id": "1070032753834438656",
#                         "name": "Political figures"
#                     }
#                 }
#             ],
#             "conversation_id": "1563562919207395331",
#             "created_at": "2022-08-27T16:23:44.000Z",
#             "entities": {
#                 "urls": [
#                     {
#                         "display_url": "twitter.com/gop/status/156\u2026",
#                         "end": 72,
#                         "expanded_url": "https://twitter.com/gop/status/1563544617555210240",
#                         "start": 49,
#                         "url": "https://t.co/mSZ6D7cjm8"
#                     }
#                 ]
#             },
#             "id": "1563562919207395331",
#             "lang": "en",
#             "possibly_sensitive": false,
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 0
#             },
#             "referenced_tweets": [
#                 {
#                     "id": "1563544617555210240",
#                     "type": "quoted"
#                 }
#             ],
#             "reply_settings": "everyone",
#             "source": "Twitter for iPhone",
#             "text": "Habitual tax cheats are now in panic mode!!!\n\ud83d\ude0e\ud83d\ude0e\ud83d\ude0e https://t.co/mSZ6D7cjm8"
#         },
#         {
#             "author_id": "1475050585565057035",
#             "conversation_id": "1563562917106434054",
#             "created_at": "2022-08-27T16:23:43.000Z",
#             "entities": {
#                 "mentions": [
#                     {
#                         "end": 18,
#                         "id": "75343905",
#                         "start": 3,
#                         "username": "calvinrobinson"
#                     }
#                 ]
#             },
#             "id": "1563562917106434054",
#             "lang": "en",
#             "possibly_sensitive": false,
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 2072
#             },
#             "referenced_tweets": [
#                 {
#                     "id": "1563226584445636611",
#                     "type": "retweeted"
#                 }
#             ],
#             "reply_settings": "everyone",
#             "source": "Twitter for iPad",
#             "text": "RT @calvinrobinson: This is a fight between good and evil. This isn\u2019t a time to be politically correct. \n\nDon\u2019t be afraid of hurty words. L\u2026"
#         },
#         {
#             "author_id": "1474360256016924678",
#             "conversation_id": "1563562916565368833",
#             "created_at": "2022-08-27T16:23:43.000Z",
#             "entities": {
#                 "hashtags": [
#                     {
#                         "end": 109,
#                         "start": 101,
#                         "tag": "GIZ_PCP"
#                     }
#                 ],
#                 "mentions": [
#                     {
#                         "end": 10,
#                         "id": "1472213442383728646",
#                         "start": 3,
#                         "username": "GizAfg"
#                     },
#                     {
#                         "end": 22,
#                         "id": "1468983850487451652",
#                         "start": 12,
#                         "username": "farid4035"
#                     },
#                     {
#                         "end": 33,
#                         "id": "1469264387512979461",
#                         "start": 23,
#                         "username": "ABaerbock"
#                     },
#                     {
#                         "end": 46,
#                         "id": "620221740",
#                         "start": 34,
#                         "username": "NancyFaeser"
#                     },
#                     {
#                         "end": 63,
#                         "id": "757979230244368385",
#                         "start": 47,
#                         "username": "SvenjaSchulze68"
#                     },
#                     {
#                         "end": 80,
#                         "id": "273468342",
#                         "start": 64,
#                         "username": "AuswaertigesAmt"
#                     },
#                     {
#                         "end": 90,
#                         "id": "22039274",
#                         "start": 81,
#                         "username": "giz_gmbh"
#                     }
#                 ]
#             },
#             "id": "1563562916565368833",
#             "lang": "en",
#             "possibly_sensitive": false,
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 2
#             },
#             "referenced_tweets": [
#                 {
#                     "id": "1563555321410617345",
#                     "type": "retweeted"
#                 }
#             ],
#             "reply_settings": "everyone",
#             "source": "Twitter for Android",
#             "text": "RT @GizAfg: @farid4035 @ABaerbock @NancyFaeser @SvenjaSchulze68 @AuswaertigesAmt @giz_gmbh We All of #GIZ_PCP faced with really bad situati\u2026"
#         },
#         {
#             "author_id": "1288923419677986820",
#             "conversation_id": "1563562915562590209",
#             "created_at": "2022-08-27T16:23:43.000Z",
#             "entities": {
#                 "mentions": [
#                     {
#                         "end": 13,
#                         "id": "2420848054",
#                         "start": 3,
#                         "username": "Leslieoo7"
#                     }
#                 ]
#             },
#             "id": "1563562915562590209",
#             "lang": "en",
#             "possibly_sensitive": false,
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 14
#             },
#             "referenced_tweets": [
#                 {
#                     "id": "1563560551703228416",
#                     "type": "retweeted"
#                 }
#             ],
#             "reply_settings": "everyone",
#             "source": "Twitter Web App",
#             "text": "RT @Leslieoo7: Dear MAGA, \n\nThis guy doesn't scare us and he certainly doesn't own us. We just think he's a corrupt slime ball and anyone w\u2026"
#         },
#         {
#             "author_id": "1318667333959909378",
#             "conversation_id": "1563562906934882305",
#             "created_at": "2022-08-27T16:23:41.000Z",
#             "id": "1563562906934882305",
#             "lang": "en",
#             "possibly_sensitive": false,
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 0
#             },
#             "reply_settings": "everyone",
#             "source": "Cheap Bots, Done Quick!",
#             "text": "I pushed him away and his costume ripped. I considered flashing my teeth to scare him, but it probably would've encouraged him!"
#         },
#         {
#             "author_id": "1483439745900462091",
#             "conversation_id": "1563562904711966721",
#             "created_at": "2022-08-27T16:23:40.000Z",
#             "entities": {
#                 "mentions": [
#                     {
#                         "end": 16,
#                         "id": "1478623645958291456",
#                         "start": 3,
#                         "username": "OmidSaboori2"
#                     }
#                 ]
#             },
#             "id": "1563562904711966721",
#             "lang": "fa",
#             "possibly_sensitive": false,
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 2
#             },
#             "referenced_tweets": [
#                 {
#                     "id": "1563554839141171211",
#                     "type": "retweeted"
#                 }
#             ],
#             "reply_settings": "everyone",
#             "source": "Twitter for Android",
#             "text": "RT @OmidSaboori2: \u062f\u0631 \u062f\u0633\u0627\u0645\u0628\u0631 1992\u060c \u0627\u0645\u0631\u06cc\u06a9\u0627 \u062f\u0631 \u0639\u0645\u0644\u06cc\u0627\u062a (\u062d\u0641\u0638 \u062f\u0645\u0648\u06a9\u0631\u0627\u0633\u06cc) \u06cc\u0627 (Operation Uphold Democracy)\u060c \u062f\u0631 \u0631\u0627\u0633\u062a\u0627\u06cc \u062d\u0645\u0627\u06cc\u062a \u0627\u0632 \u0631\u0626\u06cc\u0633 \u062c\u0645\u0647\u0648\u0631 \u0645\u062e\u0644\u0648\u0639 \u0633\u0648\u0645\u0627\u2026"
#         },
#         {
#             "author_id": "1353317091634520064",
#             "conversation_id": "1563562904435118080",
#             "created_at": "2022-08-27T16:23:40.000Z",
#             "id": "1563562904435118080",
#             "lang": "en",
#             "possibly_sensitive": false,
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 0
#             },
#             "reply_settings": "everyone",
#             "source": "Cheap Bots, Done Quick!",
#             "text": "Mega Hurts vs Terror Turtle"
#         },
#         {
#             "author_id": "1086392891272908805",
#             "context_annotations": [
#                 {
#                     "domain": {
#                         "description": "A taxonomy view into the Semantic Core knowledge graph",
#                         "id": "131",
#                         "name": "Unified Twitter Taxonomy"
#                     },
#                     "entity": {
#                         "id": "1265415402915393537",
#                         "name": "Climate change"
#                     }
#                 }
#             ],
#             "conversation_id": "1563562900236562432",
#             "created_at": "2022-08-27T16:23:39.000Z",
#             "entities": {
#                 "mentions": [
#                     {
#                         "end": 16,
#                         "id": "250346555",
#                         "start": 3,
#                         "username": "Tefere_Gebre"
#                     },
#                     {
#                         "end": 125,
#                         "id": "122961854",
#                         "start": 111,
#                         "username": "CAlegislature"
#                     }
#                 ]
#             },
#             "id": "1563562900236562432",
#             "lang": "en",
#             "possibly_sensitive": false,
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 44
#             },
#             "referenced_tweets": [
#                 {
#                     "id": "1562824399429849090",
#                     "type": "retweeted"
#                 }
#             ],
#             "reply_settings": "everyone",
#             "source": "Twitter for iPhone",
#             "text": "RT @Tefere_Gebre: READ:The oil &amp; gas industry loves to use baseless claims of job destruction to scare the @CALegislature when climate come\u2026"
#         },
#         {
#             "author_id": "1483757104104148994",
#             "conversation_id": "1563562899255492608",
#             "created_at": "2022-08-27T16:23:39.000Z",
#             "entities": {
#                 "hashtags": [
#                     {
#                         "end": 132,
#                         "start": 118,
#                         "tag": "Panic_pandemy"
#                     }
#                 ],
#                 "mentions": [
#                     {
#                         "end": 13,
#                         "id": "1406534752371458050",
#                         "start": 3,
#                         "username": "nahideh08"
#                     },
#                     {
#                         "end": 31,
#                         "id": "532802724",
#                         "start": 15,
#                         "username": "HashteSubhDaily"
#                     }
#                 ]
#             },
#             "id": "1563562899255492608",
#             "lang": "fa",
#             "possibly_sensitive": false,
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 2
#             },
#             "referenced_tweets": [
#                 {
#                     "id": "1563450611424968704",
#                     "type": "retweeted"
#                 }
#             ],
#             "reply_settings": "everyone",
#             "source": "Twitter for Android",
#             "text": "RT @nahideh08: @HashteSubhDaily \u0628\u06cc\u0627 \u0628\u0631\u0648 \u06af\u067e \u0645\u0641\u062a \u0646\u0632\u0646 \u0644\u0648\u062f\u0647\n\u062a\u0648 \u062e\u0648\u062f\u062a \u062a\u0631\u0648\u0631\u06cc\u0633\u062a \u0627\u0639\u0638\u0645 \u0627\u0633\u062a\u06cc \u06a9\u0647 \u0632\u0646\u0627\u0646 \u0648 \u06a9\u0648\u062f\u06a9\u0627\u0646 \u0645\u0627 \u0631\u0627 \u0628\u0647 \u06a9\u0634\u062a\u0646 \u062f\u0627\u062f\u06cc\n#Panic_pandemy"
#         },
#         {
#             "author_id": "48599686",
#             "context_annotations": [
#                 {
#                     "domain": {
#                         "description": "States, provinces, or prefectures, like California or Fukushima Prefecture",
#                         "id": "159",
#                         "name": "States"
#                     },
#                     "entity": {
#                         "description": "Texas",
#                         "id": "855432197297192961",
#                         "name": "Texas"
#                     }
#                 },
#                 {
#                     "domain": {
#                         "description": "States, provinces, or prefectures, like California or Fukushima Prefecture",
#                         "id": "159",
#                         "name": "States"
#                     },
#                     "entity": {
#                         "description": "California",
#                         "id": "856860158428798977",
#                         "name": "California"
#                     }
#                 }
#             ],
#             "conversation_id": "1563562897934266375",
#             "created_at": "2022-08-27T16:23:39.000Z",
#             "entities": {
#                 "annotations": [
#                     {
#                         "end": 16,
#                         "normalized_text": "Texas",
#                         "probability": 0.8396,
#                         "start": 12,
#                         "type": "Place"
#                     },
#                     {
#                         "end": 74,
#                         "normalized_text": "California",
#                         "probability": 0.9953,
#                         "start": 65,
#                         "type": "Place"
#                     },
#                     {
#                         "end": 105,
#                         "normalized_text": "Texas",
#                         "probability": 0.9885,
#                         "start": 101,
#                         "type": "Place"
#                     }
#                 ],
#                 "urls": [
#                     {
#                         "description": "The billboards mention Uvalde, include an image of a person wearing a hooded sweatshirt and boast a red X through the \"Don't mess with Texas\" slogan.",
#                         "display_url": "newsweek.com/billboards-war\u2026",
#                         "end": 148,
#                         "expanded_url": "https://www.newsweek.com/billboards-warn-california-residents-not-move-texas-after-mass-exodus-1737368",
#                         "start": 125,
#                         "status": 200,
#                         "title": "Billboards warn California residents not to move to Texas after mass exodus",
#                         "unwound_url": "https://www.newsweek.com/billboards-warn-california-residents-not-move-texas-after-mass-exodus-1737368",
#                         "url": "https://t.co/YdVvoTS1dP"
#                     }
#                 ]
#             },
#             "id": "1563562897934266375",
#             "lang": "en",
#             "possibly_sensitive": true,
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 0
#             },
#             "reply_settings": "everyone",
#             "source": "Twitter Web App",
#             "text": "Hmmm.   Are Texas MAGAts afraid of Californians? Billboards warn California residents not to move to Texas after mass exodus https://t.co/YdVvoTS1dP"
#         },
#         {
#             "author_id": "1467256617142034437",
#             "context_annotations": [
#                 {
#                     "domain": {
#                         "description": "Named people in the world like Nelson Mandela",
#                         "id": "10",
#                         "name": "Person"
#                     },
#                     "entity": {
#                         "id": "1443277565393719296",
#                         "name": "Hello Kitty"
#                     }
#                 },
#                 {
#                     "domain": {
#                         "description": "Brands and Companies",
#                         "id": "47",
#                         "name": "Brand"
#                     },
#                     "entity": {
#                         "id": "1443277565393719296",
#                         "name": "Hello Kitty"
#                     }
#                 },
#                 {
#                     "domain": {
#                         "description": "A person or other being in a narrative work of art, like Tom Sawyer or Jon Snow",
#                         "id": "122",
#                         "name": "Fictional Character"
#                     },
#                     "entity": {
#                         "id": "1443277565393719296",
#                         "name": "Hello Kitty"
#                     }
#                 },
#                 {
#                     "domain": {
#                         "description": "A taxonomy view into the Semantic Core knowledge graph",
#                         "id": "131",
#                         "name": "Unified Twitter Taxonomy"
#                     },
#                     "entity": {
#                         "id": "1443277565393719296",
#                         "name": "Hello Kitty"
#                     }
#                 }
#             ],
#             "conversation_id": "1563562897636487168",
#             "created_at": "2022-08-27T16:23:39.000Z",
#             "entities": {
#                 "mentions": [
#                     {
#                         "end": 11,
#                         "id": "1360459352830795782",
#                         "start": 3,
#                         "username": "aantcsz"
#                     }
#                 ]
#             },
#             "id": "1563562897636487168",
#             "lang": "en",
#             "possibly_sensitive": false,
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 498
#             },
#             "referenced_tweets": [
#                 {
#                     "id": "1563379355346120707",
#                     "type": "retweeted"
#                 }
#             ],
#             "reply_settings": "everyone",
#             "source": "Twitter for Android",
#             "text": "RT @aantcsz: No babe ur hello kitty obsession is perfect the normal women scare me"
#         },
#         {
#             "author_id": "1045362179023810560",
#             "conversation_id": "1563562896449159168",
#             "created_at": "2022-08-27T16:23:38.000Z",
#             "entities": {
#                 "annotations": [
#                     {
#                         "end": 104,
#                         "normalized_text": "FL",
#                         "probability": 0.988,
#                         "start": 103,
#                         "type": "Place"
#                     }
#                 ],
#                 "mentions": [
#                     {
#                         "end": 16,
#                         "id": "1298049595495182338",
#                         "start": 3,
#                         "username": "jasondogwood"
#                     }
#                 ]
#             },
#             "id": "1563562896449159168",
#             "lang": "en",
#             "possibly_sensitive": false,
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 358
#             },
#             "referenced_tweets": [
#                 {
#                     "id": "1563498278846472193",
#                     "type": "retweeted"
#                 }
#             ],
#             "reply_settings": "everyone",
#             "source": "Twitter for Android",
#             "text": "RT @jasondogwood: I will NOT stop sounding this alarm.  \n\nI just watched an hour of local news here in FL &amp; saw about 6 six pro-republican\u2026"
#         },
#         {
#             "author_id": "59300388",
#             "context_annotations": [
#                 {
#                     "domain": {
#                         "description": "Named people in the world like Nelson Mandela",
#                         "id": "10",
#                         "name": "Person"
#                     },
#                     "entity": {
#                         "description": "45th US President, Donald Trump",
#                         "id": "799022225751871488",
#                         "name": "Donald Trump"
#                     }
#                 },
#                 {
#                     "domain": {
#                         "description": "Politicians in the world, like Joe Biden",
#                         "id": "35",
#                         "name": "Politician"
#                     },
#                     "entity": {
#                         "description": "45th US President, Donald Trump",
#                         "id": "799022225751871488",
#                         "name": "Donald Trump"
#                     }
#                 },
#                 {
#                     "domain": {
#                         "description": "A taxonomy view into the Semantic Core knowledge graph",
#                         "id": "131",
#                         "name": "Unified Twitter Taxonomy"
#                     },
#                     "entity": {
#                         "description": "45th US President, Donald Trump",
#                         "id": "799022225751871488",
#                         "name": "Donald Trump"
#                     }
#                 },
#                 {
#                     "domain": {
#                         "description": "A taxonomy view into the Semantic Core knowledge graph",
#                         "id": "131",
#                         "name": "Unified Twitter Taxonomy"
#                     },
#                     "entity": {
#                         "description": "Politics",
#                         "id": "847878884917886977",
#                         "name": "Politics"
#                     }
#                 },
#                 {
#                     "domain": {
#                         "description": "A taxonomy view into the Semantic Core knowledge graph",
#                         "id": "131",
#                         "name": "Unified Twitter Taxonomy"
#                     },
#                     "entity": {
#                         "description": "Politician",
#                         "id": "1070032753834438656",
#                         "name": "Political figures"
#                     }
#                 },
#                 {
#                     "domain": {
#                         "description": "A taxonomy view into the Semantic Core knowledge graph",
#                         "id": "131",
#                         "name": "Unified Twitter Taxonomy"
#                     },
#                     "entity": {
#                         "id": "1427352573401452555",
#                         "name": "Crisis in Afghanistan"
#                     }
#                 }
#             ],
#             "conversation_id": "1563562893307965440",
#             "created_at": "2022-08-27T16:23:38.000Z",
#             "entities": {
#                 "annotations": [
#                     {
#                         "end": 4,
#                         "normalized_text": "trump",
#                         "probability": 0.9953,
#                         "start": 0,
#                         "type": "Person"
#                     },
#                     {
#                         "end": 75,
#                         "normalized_text": "USA",
#                         "probability": 0.976,
#                         "start": 73,
#                         "type": "Place"
#                     }
#                 ],
#                 "urls": [
#                     {
#                         "display_url": "twitter.com/FoxNews/status\u2026",
#                         "end": 101,
#                         "expanded_url": "https://twitter.com/FoxNews/status/1563560749384904705",
#                         "start": 78,
#                         "url": "https://t.co/RYHyGbYWGZ"
#                     }
#                 ]
#             },
#             "id": "1563562893307965440",
#             "lang": "en",
#             "possibly_sensitive": false,
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 0
#             },
#             "referenced_tweets": [
#                 {
#                     "id": "1563560749384904705",
#                     "type": "quoted"
#                 }
#             ],
#             "reply_settings": "everyone",
#             "source": "Twitter Web App",
#             "text": "trump made the Afgan withdrawl agreement before his terror attack on the USA. https://t.co/RYHyGbYWGZ"
#         },
#         {
#             "author_id": "1482090851979468806",
#             "conversation_id": "1563562893228281856",
#             "created_at": "2022-08-27T16:23:37.000Z",
#             "entities": {
#                 "mentions": [
#                     {
#                         "end": 17,
#                         "id": "201237617",
#                         "start": 3,
#                         "username": "firstladyship"
#                     }
#                 ]
#             },
#             "id": "1563562893228281856",
#             "lang": "en",
#             "possibly_sensitive": false,
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 1645
#             },
#             "referenced_tweets": [
#                 {
#                     "id": "1563426879419580416",
#                     "type": "retweeted"
#                 }
#             ],
#             "reply_settings": "everyone",
#             "source": "Twitter for Android",
#             "text": "RT @firstladyship: My People, our Kaduna rally is canceled. El-Rufai have no liver, no balls. He chickened out at the last minute. Ruffy us\u2026"
#         },
#         {
#             "author_id": "1422690740820398084",
#             "conversation_id": "1563562892263575553",
#             "created_at": "2022-08-27T16:23:37.000Z",
#             "entities": {
#                 "hashtags": [
#                     {
#                         "end": 208,
#                         "start": 198,
#                         "tag": "SayNoMore"
#                     },
#                     {
#                         "end": 224,
#                         "start": 209,
#                         "tag": "TPLFistheCause"
#                     },
#                     {
#                         "end": 243,
#                         "start": 226,
#                         "tag": "EthiopiaPrevails"
#                     }
#                 ]
#             },
#             "id": "1563562892263575553",
#             "lang": "en",
#             "possibly_sensitive": false,
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 0
#             },
#             "reply_settings": "everyone",
#             "source": "Twitter for iPhone",
#             "text": "The ppls &amp; govts of Ethiopia, Eritrea &amp; Somalia have a right to defend their nations against terror by TPLF &amp; other armed groups. They have a right to pursue their own political vision. #SayNoMore #TPLFistheCause  #EthiopiaPrevails"
#         },
#         {
#             "attachments": {
#                 "media_keys": [
#                     "3_1563562888388030472"
#                 ]
#             },
#             "author_id": "1268296045491978240",
#             "conversation_id": "1563560858101239808",
#             "created_at": "2022-08-27T16:23:37.000Z",
#             "entities": {
#                 "mentions": [
#                     {
#                         "end": 16,
#                         "id": "1545540224079609863",
#                         "start": 0,
#                         "username": "doubleTwretched"
#                     }
#                 ],
#                 "urls": [
#                     {
#                         "display_url": "pic.twitter.com/UnF1mAYzWc",
#                         "end": 60,
#                         "expanded_url": "https://twitter.com/Da_T00n/status/1563562892150337536/photo/1",
#                         "media_key": "3_1563562888388030472",
#                         "start": 37,
#                         "url": "https://t.co/UnF1mAYzWc"
#                     }
#                 ]
#             },
#             "id": "1563562892150337536",
#             "in_reply_to_user_id": "1545540224079609863",
#             "lang": "en",
#             "possibly_sensitive": false,
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 1
#             },
#             "referenced_tweets": [
#                 {
#                     "id": "1563562735656640513",
#                     "type": "replied_to"
#                 }
#             ],
#             "reply_settings": "everyone",
#             "source": "Twitter for iPhone",
#             "text": "@doubleTwretched Retweet to scare TT https://t.co/UnF1mAYzWc"
#         },
#         {
#             "author_id": "1483757104104148994",
#             "conversation_id": "1563562890103525376",
#             "created_at": "2022-08-27T16:23:37.000Z",
#             "entities": {
#                 "mentions": [
#                     {
#                         "end": 14,
#                         "id": "2894148313",
#                         "start": 3,
#                         "username": "Moqadasa12"
#                     }
#                 ]
#             },
#             "id": "1563562890103525376",
#             "lang": "ps",
#             "possibly_sensitive": false,
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 7
#             },
#             "referenced_tweets": [
#                 {
#                     "id": "1563450610904866817",
#                     "type": "retweeted"
#                 }
#             ],
#             "reply_settings": "everyone",
#             "source": "Twitter for Android",
#             "text": "RT @Moqadasa12: \u0627\u0645\u0631\u064a\u06a9\u0627\u064a\u0627\u0646\u0648 \u0645\u0648\u0696 \u062a\u0647 \u0646\u0647 \u062f\u0627 \u0686\u06d0 \u064a\u0648\u0627\u0632\u06d0 \u0648\u0698\u0646\u06d0 \u0631\u0627\u0648\u0693\u06d0 \u0648\u06d0\u060c \u0628\u0644\u06a9\u06d0 \u062f\u0644\u062a\u0647 \u064a\u06d0 \u06a9\u0644\u062a\u0648\u0631\u064a \u064a\u0631\u063a\u0644 \u06a9\u0693\u06cc \u0648\u060c \u0645\u0630\u0647\u0628\u064a \u064a\u0631\u063a\u0644 \u06a9\u0693\u06cc \u0648\u060c \u0628\u062f\u0628\u062e\u062a\u064a \u0631\u0627\u0648\u0693\u06d0 \u0648\u06d0\u060c \u062f\u0644\u062a\u0647 \u064a\u06d0\u2026"
#         },
#         {
#             "author_id": "1459869753325936640",
#             "context_annotations": [
#                 {
#                     "domain": {
#                         "description": "Named people in the world like Nelson Mandela",
#                         "id": "10",
#                         "name": "Person"
#                     },
#                     "entity": {
#                         "id": "1515470636843343877",
#                         "name": "Peter Obi"
#                     }
#                 },
#                 {
#                     "domain": {
#                         "description": "Politicians in the world, like Joe Biden",
#                         "id": "35",
#                         "name": "Politician"
#                     },
#                     "entity": {
#                         "id": "1515470636843343877",
#                         "name": "Peter Obi"
#                     }
#                 },
#                 {
#                     "domain": {
#                         "description": "A taxonomy view into the Semantic Core knowledge graph",
#                         "id": "131",
#                         "name": "Unified Twitter Taxonomy"
#                     },
#                     "entity": {
#                         "description": "Politics",
#                         "id": "847878884917886977",
#                         "name": "Politics"
#                     }
#                 },
#                 {
#                     "domain": {
#                         "description": "A taxonomy view into the Semantic Core knowledge graph",
#                         "id": "131",
#                         "name": "Unified Twitter Taxonomy"
#                     },
#                     "entity": {
#                         "description": "Politician",
#                         "id": "1070032753834438656",
#                         "name": "Political figures"
#                     }
#                 },
#                 {
#                     "domain": {
#                         "description": "A taxonomy view into the Semantic Core knowledge graph",
#                         "id": "131",
#                         "name": "Unified Twitter Taxonomy"
#                     },
#                     "entity": {
#                         "id": "1515470636843343877",
#                         "name": "Peter Obi"
#                     }
#                 },
#                 {
#                     "domain": {
#                         "description": "A taxonomy view into the Semantic Core knowledge graph",
#                         "id": "131",
#                         "name": "Unified Twitter Taxonomy"
#                     },
#                     "entity": {
#                         "id": "1518657936511279104",
#                         "name": "Nigeria political figures"
#                     }
#                 }
#             ],
#             "conversation_id": "1563562889922822145",
#             "created_at": "2022-08-27T16:23:37.000Z",
#             "entities": {
#                 "annotations": [
#                     {
#                         "end": 60,
#                         "normalized_text": "El Rufai",
#                         "probability": 0.6834,
#                         "start": 53,
#                         "type": "Person"
#                     },
#                     {
#                         "end": 133,
#                         "normalized_text": "Mr. Peter Obi",
#                         "probability": 0.7814,
#                         "start": 121,
#                         "type": "Person"
#                     },
#                     {
#                         "end": 140,
#                         "normalized_text": "Kad",
#                         "probability": 0.67,
#                         "start": 138,
#                         "type": "Place"
#                     }
#                 ],
#                 "mentions": [
#                     {
#                         "end": 18,
#                         "id": "1082877821515694080",
#                         "start": 3,
#                         "username": "NGRLabourParty"
#                     }
#                 ]
#             },
#             "id": "1563562889922822145",
#             "lang": "en",
#             "possibly_sensitive": false,
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 233
#             },
#             "referenced_tweets": [
#                 {
#                     "id": "1563495757847883782",
#                     "type": "retweeted"
#                 }
#             ],
#             "reply_settings": "everyone",
#             "source": "Twitter for iPhone",
#             "text": "RT @NGRLabourParty: Question of the day:\nWhy is Gov. El Rufai afraid of just \"200 Nigerians\ud83c\uddf3\ud83c\uddec\" coming out to march for Mr. Peter Obi in Kad\u2026"
#         },
#         {
#             "author_id": "2885998073",
#             "context_annotations": [
#                 {
#                     "domain": {
#                         "description": "Named people in the world like Nelson Mandela",
#                         "id": "10",
#                         "name": "Person"
#                     },
#                     "entity": {
#                         "id": "1338352476093726721",
#                         "name": "Wang Yibo"
#                     }
#                 },
# ...
#             },
#             {
#                 "created_at": "2012-06-25T16:50:28.000Z",
#                 "description": "Lifetime Democrat worried for our democracy. Pro Choice, BLM, love is love. Happily married; no DMs.",
#                 "id": "618246617",
#                 "name": "Diane Christensen \u262e\ufe0f",
#                 "public_metrics": {
#                     "followers_count": 1143,
#                     "following_count": 1723,
#                     "listed_count": 2,
#                     "tweet_count": 5748
#                 },
#                 "username": "djshawnsmom",
#                 "verified": false
#             },
#             {
#                 "created_at": "2020-02-09T14:59:49.000Z",
#                 "description": "JustForFun",
#                 "id": "1226521010603560965",
#                 "name": "Naz",
#                 "public_metrics": {
#                     "followers_count": 16,
#                     "following_count": 31,
#                     "listed_count": 0,
#                     "tweet_count": 299
#                 },
#                 "username": "yuen_box",
#                 "verified": false
#             },
#             {
#                 "created_at": "2017-05-26T02:59:38.000Z",
#                 "description": "Columbia. Stanford,  Former Marine combat company commander Anti socialist, Anti communist. Pro MAGA.",
#                 "id": "867938245832695809",
#                 "name": "Warbuck57",
#                 "public_metrics": {
#                     "followers_count": 1843,
#                     "following_count": 2372,
#                     "listed_count": 1,
#                     "tweet_count": 40118
#                 },
#                 "username": "Warbuck571",
#                 "verified": false
#             },
#             {
#                 "created_at": "2020-01-17T02:48:46.000Z",
#                 "description": "Casual Sonic Lore Master | Certified SonicTuber | Amphibia Connoisseur | \"Local, Loveable Trouble Maker\" | YouTube art by @D_Doe62 | Host of @station_sonic",
#                 "id": "1218002140054069248",
#                 "name": "XPool",
#                 "public_metrics": {
#                     "followers_count": 568,
#                     "following_count": 385,
#                     "listed_count": 4,
#                     "tweet_count": 9654
#                 },
#                 "username": "Cars2Gamer",
#                 "verified": false
#             },
#             {
#                 "created_at": "2020-01-17T00:04:08.000Z",
#                 "description": "Nerdy, dirty, inked, and curvy\nSLE & Fibro queen. Taken. \ud83d\udeab DMs \n\nhttps://t.co/MAujRwBrHa",
#                 "id": "1217960673239498753",
#                 "name": "CrazyAF\ud83e\udd9bButCute",
#                 "public_metrics": {
#                     "followers_count": 219895,
#                     "following_count": 10869,
#                     "listed_count": 187,
#                     "tweet_count": 286949
#                 },
#                 "username": "Crazy_ButCute2",
#                 "verified": false
#             },
#             {
#                 "created_at": "2011-03-13T00:54:07.000Z",
#                 "description": "https://t.co/JKvoNKU1jx I drop every Tuesday, add me to your playlist. put ya ppl on. LOVE\ud83c\udf7e",
#                 "id": "265093663",
#                 "name": "Bossplaya",
#                 "public_metrics": {
#                     "followers_count": 904,
#                     "following_count": 438,
#                     "listed_count": 9,
#                     "tweet_count": 32308
#                 },
#                 "username": "YoungDV_MLK",
#                 "verified": false
#             },
#             {
#                 "created_at": "2014-04-01T15:38:26.000Z",
#                 "description": "Animation, video game, and puppet fan and 1/3 of Muppet Fans Talking. Any pronouns! No NSFW stuff please. @NerdyMariaMania \ud83d\udc9b\ud83d\udc9b\ud83d\udc9b",
#                 "id": "2422289221",
#                 "name": "(Down and) Sprout\ud83d\udcab",
#                 "public_metrics": {
#                     "followers_count": 554,
#                     "following_count": 388,
#                     "listed_count": 12,
#                     "tweet_count": 28643
#                 },
#                 "username": "paopusprout",
#                 "verified": false
#             },
#             {
#                 "created_at": "2020-03-18T20:45:24.000Z",
#                 "description": "A bot that believes it's a graphic designer, dog mom, sister, and friend in an epic battle against the snooze button.",
#                 "id": "1240378753202696193",
#                 "name": "JessBot",
#                 "public_metrics": {
#                     "followers_count": 24,
#                     "following_count": 10,
#                     "listed_count": 0,
#                     "tweet_count": 239951
#                 },
#                 "username": "Bot_of_Jess",
#                 "verified": false
#             },
#             {
#                 "created_at": "2019-07-23T21:06:46.000Z",
#                 "description": "My country",
#                 "id": "1153773471207497728",
#                 "name": "human rights activist",
#                 "public_metrics": {
#                     "followers_count": 523,
#                     "following_count": 1185,
#                     "listed_count": 0,
#                     "tweet_count": 41225
#                 },
#                 "username": "Samuel12235343",
#                 "verified": false
#             },
#             {
#                 "created_at": "2019-12-28T17:00:28.000Z",
#                 "description": "Married to a disabled https://t.co/NI6HmLzQzR Veteran, Para Educator, bus driver, for a PreK-12 school in NE. No DMs please.",
#                 "id": "1210968543455375362",
#                 "name": "Susan",
#                 "public_metrics": {
#                     "followers_count": 690,
#                     "following_count": 760,
#                     "listed_count": 0,
#                     "tweet_count": 14030
#                 },
#                 "username": "Reddie2019",
#                 "verified": false
#             },
#             {
#                 "created_at": "2020-04-17T16:45:05.000Z",
#                 "description": "I'm worthless",
#                 "id": "1251189767485689857",
#                 "name": "annie van Dijk",
#                 "public_metrics": {
#                     "followers_count": 25,
#                     "following_count": 125,
#                     "listed_count": 0,
#                     "tweet_count": 356
#                 },
#                 "username": "annievanDijk7",
#                 "verified": false
#             },
#             {
#                 "created_at": "2019-10-12T06:48:19.000Z",
#                 "description": "Metal Head / Gamer / Computer engineering Student",
#                 "id": "1182910823062212608",
#                 "name": "KainAlvaine",
#                 "public_metrics": {
#                     "followers_count": 108,
#                     "following_count": 3272,
#                     "listed_count": 7,
#                     "tweet_count": 8556
#                 },
#                 "username": "KainAlvaine",
#                 "verified": false
#             },
#             {
#                 "created_at": "2022-05-31T13:36:04.000Z",
#                 "description": "FANDOMLESS\n\nHere for my love @itsmetejasswi \u2764 Love dis cutie soooo much\u2764 \n\n11:11 manifesting \nBappa bless her with all d love ,happiness & success ahead",
#                 "id": "1531630387772141569",
#                 "name": "Brighty\u2764\u0924\u0947\u091c\u0942",
#                 "public_metrics": {
#                     "followers_count": 44,
#                     "following_count": 62,
#                     "listed_count": 0,
#                     "tweet_count": 17229
#                 },
#                 "username": "brighty_teju",
#                 "verified": false
#             },
#             {
#                 "created_at": "2019-02-07T21:39:13.000Z",
#                 "description": "Writer of Horror and Queer Romance \u2022 Satanist  \u2022 Socialist  \u2022  Animal Science Major \u2022 PFP by @DerpyJackArts",
#                 "id": "1093625250204528640",
#                 "name": "egirl Cthulhu \ud83c\udf08 #DropKiwiFarms",
#                 "public_metrics": {
#                     "followers_count": 670,
#                     "following_count": 5002,
#                     "listed_count": 4,
#                     "tweet_count": 37224
#                 },
#                 "username": "AudreyyOwO",
#                 "verified": false
#             },
#             {
#                 "created_at": "2014-11-20T22:21:16.000Z",
#                 "description": "The Metaverse is Liquid.",
#                 "id": "2886207743",
#                 "name": "Go West",
#                 "public_metrics": {
#                     "followers_count": 2014,
#                     "following_count": 4210,
#                     "listed_count": 9,
#                     "tweet_count": 71588
#                 },
#                 "username": "arthurjerome247",
#                 "verified": false
#             },
#             {
#                 "created_at": "2009-10-01T22:21:51.000Z",
#                 "description": "Punch Nazis &communists\ud83d\udc4a\ud83c\udffc\ud83d\udca5\u2199\ufe0f\u2199\ufe0f\u2199\ufe0f, pro choice Neil Gaiman,\ud83c\uddef\ud83c\uddf5\u65e5\u672c, DNC, \ud83d\udc31rescue, TNR INFJ \ud83e\udd96\u05e9\u05dc\u05d5\u05dd \u062d\u0628\ud83c\uddf5\ud83c\uddf8\ud83c\uddee\ud83c\uddf1NASA NI\u0418 \ud83c\uddfa\ud83c\uddf8\ud83c\uddec\ud83c\uddf9\ud83c\uddfa\ud83c\udde6chapin \ud83c\udf08\u267b\ufe0f.\ud83d\udd95\ud83c\udffdfk Putin",
#                 "id": "79019935",
#                 "name": "R. M\u00f4nzon \ud83c\uddfa\ud83c\udde6\ud83c\udf3b11:11",
#                 "public_metrics": {
#                     "followers_count": 419,
#                     "following_count": 1450,
#                     "listed_count": 25,
#                     "tweet_count": 10091
#                 },
#                 "username": "NowImNothing_",
#                 "verified": false
#             },
#             {
#                 "created_at": "2019-08-18T01:07:44.000Z",
#                 "description": "",
#                 "id": "1162893769739558912",
#                 "name": "moe f",
#                 "public_metrics": {
#                     "followers_count": 157,
#                     "following_count": 97,
#                     "listed_count": 0,
#                     "tweet_count": 5041
#                 },
#                 "username": "maureen09316932",
#                 "verified": false
#             },
#             {
#                 "created_at": "2012-02-16T03:21:25.000Z",
#                 "description": "Author of 'If God is Love, Don't Be a Jerk\u2019 Love your neighbor: get vaccinated. This is about more than you.",
#                 "id": "493714995",
#                 "name": "John Pavlovitz",
#                 "public_metrics": {
#                     "followers_count": 407872,
#                     "following_count": 32812,
#                     "listed_count": 2239,
#                     "tweet_count": 139808
#                 },
#                 "username": "johnpavlovitz",
#                 "verified": true
#             },
#             {
#                 "created_at": "2014-10-11T00:30:37.000Z",
#                 "description": "Retired Engineer, Student at Wayne State University in Detroit. #grossepointeantifa",
#                 "id": "2851365583",
#                 "name": "Greg Urbiel",
#                 "public_metrics": {
#                     "followers_count": 734,
#                     "following_count": 1079,
#                     "listed_count": 0,
#                     "tweet_count": 38544
#                 },
#                 "username": "gregurbiel",
#                 "verified": false
#             },
#             {
#                 "created_at": "2014-07-13T16:03:55.000Z",
#                 "description": "gay/bored/Furry/23/M/uuuuhhhhh\n\nart by @rawr3108",
#                 "id": "2707427361",
#                 "name": "BlackStarDaWolf",
#                 "public_metrics": {
#                     "followers_count": 35,
#                     "following_count": 165,
#                     "listed_count": 0,
#                     "tweet_count": 1197
#                 },
#                 "username": "greywolf422",
#                 "verified": false
#             },
#             {
#                 "created_at": "2011-03-12T02:04:45.000Z",
#                 "description": "Mujer chilena sin ideolog\u00edas pol\u00edticas, defensora de la vida.  Apoyo las ideas justas y con sentido com\u00fan. Patriota. Ingeniero Comercial.",
#                 "id": "264531512",
#                 "name": "Carolina",
#                 "public_metrics": {
#                     "followers_count": 231,
#                     "following_count": 1057,
#                     "listed_count": 0,
#                     "tweet_count": 2257
#                 },
#                 "username": "VeamosLoBueno",
#                 "verified": false
#             },
#             {
#                 "created_at": "2021-08-09T17:49:06.000Z",
#                 "description": "\ud83c\udf0d\ud83d\udc9c",
#                 "id": "1424789776289320964",
#                 "name": "~hobaaa^\u00b0^~",
#                 "public_metrics": {
#                     "followers_count": 61,
#                     "following_count": 102,
#                     "listed_count": 0,
#                     "tweet_count": 21112
#                 },
#                 "username": "Palak713",
#                 "verified": false
#             },
#             {
#                 "created_at": "2009-09-15T18:14:48.000Z",
#                 "description": "Raised on a steady diet of Cold War paranoia and recycled 60s pop culture",
#                 "id": "74513098",
#                 "name": "Brandon Kwiatek",
#                 "public_metrics": {
#                     "followers_count": 293,
#                     "following_count": 641,
#                     "listed_count": 7,
#                     "tweet_count": 3062
#                 },
#                 "username": "realwestband",
#                 "verified": false
#             },
#             {
#                 "created_at": "2022-03-09T23:15:31.000Z",
#                 "description": "Home Schooled in Dallavere & Shajtanllejke",
#                 "id": "1501698163056467975",
#                 "name": "Buk\u00eb E Krip",
#                 "public_metrics": {
#                     "followers_count": 27,
#                     "following_count": 93,
#                     "listed_count": 0,
#                     "tweet_count": 1320
#                 },
#                 "username": "krenarkatundar",
#                 "verified": false
#             },
#             {
#                 "created_at": "2012-01-15T18:36:22.000Z",
#                 "description": "",
#                 "id": "464878013",
#                 "name": "arnaldur",
#                 "public_metrics": {
#                     "followers_count": 283,
#                     "following_count": 131,
#                     "listed_count": 4,
#                     "tweet_count": 51896
#                 },
#                 "username": "arnaldur1",
#                 "verified": false
#             },
#             {
#                 "created_at": "2022-07-28T13:34:38.000Z",
#                 "description": "\ud83d\ude4f\u1270\u1235\u134b \u12a5\u12e9 \u1213\u12ed\u1208\u12ed \u12cd\u123d\u1320\u12ed \u12dd\u12a3\u121d\u1290\u1209::",
#                 "id": "1552647745734905856",
#                 "name": "\u12a3\u12dc\u122d \u1275\u130d\u122b\u12c8\u12ed\u1272\ud83d\udcaf",
#                 "public_metrics": {
#                     "followers_count": 165,
#                     "following_count": 202,
#                     "listed_count": 0,
#                     "tweet_count": 35147
#                 },
#                 "username": "hrit_hailu",
#                 "verified": false
#             }
#         ]
#     },
#     "meta": {
#         "newest_id": "1563562921644343296",
#         "next_token": "b26v89c19zqg8o3fpz8l5pz0ro12g5kk7x9snhgikcg3h",
#         "oldest_id": "1563562790719143938",
#         "result_count": 100
#     }
# }

# %%
# first tweet
json_response['data'][0]

# useful to keep: author_id, id, text, created_at, context_annotations, public_metrics?, conversation_id?
# Out:
# {'text': '@RonFilipkowski @joncoopertweets This is Domestic Terror: Donald Trump, the biggest CON MAN in American History. His people bought it hook, line, and sinker. https://t.co/8zHzE3aJ0u',
#  'conversation_id': '1562459481031581697',
#  'lang': 'en',
#  'entities': {'annotations': [{'start': 58,
#     'end': 69,
#     'probability': 0.9914,
#     'type': 'Person',
#     'normalized_text': 'Donald Trump'}],
#   'mentions': [{'start': 0,
#     'end': 15,
#     'username': 'RonFilipkowski',
#     'id': '1298372735383605249'},
#    {'start': 16, 'end': 32, 'username': 'joncoopertweets', 'id': '27493883'}],
#   'urls': [{'start': 158,
#     'end': 181,
#     'url': 'https://t.co/8zHzE3aJ0u',
#     'expanded_url': 'https://twitter.com/TTj76447322/status/1563562921644343296/photo/1',
#     'display_url': 'pic.twitter.com/8zHzE3aJ0u',
#     'media_key': '3_1563562866556276736'}]},
#  'context_annotations': [{'domain': {'id': '10',
#     'name': 'Person',
#     'description': 'Named people in the world like Nelson Mandela'},
#    'entity': {'id': '799022225751871488',
#     'name': 'Donald Trump',
#     'description': '45th US President, Donald Trump'}},
#   {'domain': {'id': '10',
#     'name': 'Person',
#     'description': 'Named people in the world like Nelson Mandela'},
#    'entity': {'id': '1138106947234779137', 'name': 'Jon Cooper'}},
#   {'domain': {'id': '35',
#     'name': 'Politician',
#     'description': 'Politicians in the world, like Joe Biden'},
#    'entity': {'id': '799022225751871488',
#     'name': 'Donald Trump',
#     'description': '45th US President, Donald Trump'}},
#   {'domain': {'id': '35',
#     'name': 'Politician',
#     'description': 'Politicians in the world, like Joe Biden'},
#    'entity': {'id': '1138106947234779137', 'name': 'Jon Cooper'}},
#   {'domain': {'id': '131',
#     'name': 'Unified Twitter Taxonomy',
#     'description': 'A taxonomy view into the Semantic Core knowledge graph'},
#    'entity': {'id': '799022225751871488',
#     'name': 'Donald Trump',
#     'description': '45th US President, Donald Trump'}},
#   {'domain': {'id': '131',
#     'name': 'Unified Twitter Taxonomy',
#     'description': 'A taxonomy view into the Semantic Core knowledge graph'},
#    'entity': {'id': '847878884917886977',
#     'name': 'Politics',
#     'description': 'Politics'}},
#   {'domain': {'id': '131',
#     'name': 'Unified Twitter Taxonomy',
#     'description': 'A taxonomy view into the Semantic Core knowledge graph'},
#    'entity': {'id': '1070032753834438656',
#     'name': 'Political figures',
#     'description': 'Politician'}},
#   {'domain': {'id': '131',
#     'name': 'Unified Twitter Taxonomy',
#     'description': 'A taxonomy view into the Semantic Core knowledge graph'},
#    'entity': {'id': '1138106947234779137', 'name': 'Jon Cooper'}}],
#  'attachments': {'media_keys': ['3_1563562866556276736']},
#  'referenced_tweets': [{'type': 'replied_to', 'id': '1562459481031581697'}],
#  'source': 'Twitter Web App',
#  'id': '1563562921644343296',
#  'public_metrics': {'retweet_count': 0,
#   'reply_count': 0,
#   'like_count': 0,
#   'quote_count': 0},
#  'possibly_sensitive': False,
#  'in_reply_to_user_id': '1298372735383605249',
#  'author_id': '1555323426784456704',
#  'created_at': '2022-08-27T16:23:44.000Z',
#  'reply_settings': 'everyone'}

# %%
json_response.keys()
# Out:
# dict_keys(['data', 'includes', 'meta'])

# %%
json_response['includes']['users'][0]
# Out:
# {'name': 'T J',
#  'verified': False,
#  'created_at': '2022-08-04T22:43:19.000Z',
#  'id': '1555323426784456704',
#  'description': 'Arizona Hardworking Individual',
#  'public_metrics': {'followers_count': 5,
#   'following_count': 40,
#   'tweet_count': 387,
#   'listed_count': 0},
#  'username': 'TTj76447322'}

# %%
json_response['meta']
# Out:
# {'newest_id': '1563562921644343296',
#  'oldest_id': '1563562790719143938',
#  'result_count': 100,
#  'next_token': 'b26v89c19zqg8o3fpz8l5pz0ro12g5kk7x9snhgikcg3h'}

# %%
json_response['meta']['next_token']
# Out:
# 'b26v89c19zqg8o3fpz8l5pz0ro12g5kk7x9snhgikcg3h'

# %%
json_response['data'][0].keys()
# Out:
# dict_keys(['text', 'conversation_id', 'lang', 'entities', 'context_annotations', 'attachments', 'referenced_tweets', 'source', 'id', 'public_metrics', 'possibly_sensitive', 'in_reply_to_user_id', 'author_id', 'created_at', 'reply_settings'])

# %%
json_response['data'][0]['public_metrics'].keys()
# Out:
# dict_keys(['retweet_count', 'reply_count', 'like_count', 'quote_count'])

# %%
json_response["data"][0]["context_annotations"]
# Out:
# [{'domain': {'id': '10',
#    'name': 'Person',
#    'description': 'Named people in the world like Nelson Mandela'},
#   'entity': {'id': '799022225751871488',
#    'name': 'Donald Trump',
#    'description': '45th US President, Donald Trump'}},
#  {'domain': {'id': '10',
#    'name': 'Person',
#    'description': 'Named people in the world like Nelson Mandela'},
#   'entity': {'id': '1138106947234779137', 'name': 'Jon Cooper'}},
#  {'domain': {'id': '35',
#    'name': 'Politician',
#    'description': 'Politicians in the world, like Joe Biden'},
#   'entity': {'id': '799022225751871488',
#    'name': 'Donald Trump',
#    'description': '45th US President, Donald Trump'}},
#  {'domain': {'id': '35',
#    'name': 'Politician',
#    'description': 'Politicians in the world, like Joe Biden'},
#   'entity': {'id': '1138106947234779137', 'name': 'Jon Cooper'}},
#  {'domain': {'id': '131',
#    'name': 'Unified Twitter Taxonomy',
#    'description': 'A taxonomy view into the Semantic Core knowledge graph'},
#   'entity': {'id': '799022225751871488',
#    'name': 'Donald Trump',
#    'description': '45th US President, Donald Trump'}},
#  {'domain': {'id': '131',
#    'name': 'Unified Twitter Taxonomy',
#    'description': 'A taxonomy view into the Semantic Core knowledge graph'},
#   'entity': {'id': '847878884917886977',
#    'name': 'Politics',
#    'description': 'Politics'}},
#  {'domain': {'id': '131',
#    'name': 'Unified Twitter Taxonomy',
#    'description': 'A taxonomy view into the Semantic Core knowledge graph'},
#   'entity': {'id': '1070032753834438656',
#    'name': 'Political figures',
#    'description': 'Politician'}},
#  {'domain': {'id': '131',
#    'name': 'Unified Twitter Taxonomy',
#    'description': 'A taxonomy view into the Semantic Core knowledge graph'},
#   'entity': {'id': '1138106947234779137', 'name': 'Jon Cooper'}}]

# %% [markdown]
# ######## creating dataframe
#
# column_names = [col for col in json_response['data'][0].keys() if col != 'public_metrics'] + [col for col in json_response['data'][0]['public_metrics'].keys()]
# print(column_names)
#
# data = pd.DataFrame(columns=column_names)
# data.head()

# %%
# creating dataframe
data_1 = pd.DataFrame()

raw_data = json_response['data']

for tweet in raw_data:
    data_1 = data_1.append(tweet, ignore_index=True)

#data.drop(['public_metrics'], axis=1, inplace=True)
print(data.shape)
data_1.head()
# Out:
# (100, 16)
#                                                 text      conversation_id  \
# 0  @RonFilipkowski @joncoopertweets This is Domes...  1562459481031581697
# 1  RT @ConorGogarty: “The pain of Lily being take...  1563562919924678657
# 2  Habitual tax cheats are now in panic mode!!!\n...  1563562919207395331
# 3  RT @calvinrobinson: This is a fight between go...  1563562917106434054
# 4  RT @GizAfg: @farid4035 @ABaerbock @NancyFaeser...  1563562916565368833
#
#   lang                                           entities  \
# 0   en  {'annotations': [{'start': 58, 'end': 69, 'pro...
# 1   en  {'annotations': [{'start': 31, 'end': 34, 'pro...
# 2   en  {'urls': [{'start': 49, 'end': 72, 'url': 'htt...
# 3   en  {'mentions': [{'start': 3, 'end': 18, 'usernam...
# 4   en  {'hashtags': [{'start': 101, 'end': 109, 'tag'...
#
#                                  context_annotations  \
# 0  [{'domain': {'id': '10', 'name': 'Person', 'de...
# 1                                                NaN
# 2  [{'domain': {'id': '10', 'name': 'Person', 'de...
# 3                                                NaN
# 4                                                NaN
#
#                                  attachments  \
# 0  {'media_keys': ['3_1563562866556276736']}
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
#
#                                    referenced_tweets               source  \
# 0  [{'type': 'replied_to', 'id': '156245948103158...      Twitter Web App
# 1  [{'type': 'retweeted', 'id': '1563131038213505...      Twitter Web App
# 2  [{'type': 'quoted', 'id': '1563544617555210240'}]   Twitter for iPhone
# 3  [{'type': 'retweeted', 'id': '1563226584445636...     Twitter for iPad
# 4  [{'type': 'retweeted', 'id': '1563555321410617...  Twitter for Android
#
#                     id                                     public_metrics  \
# 0  1563562921644343296  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 1  1563562919924678657  {'retweet_count': 244, 'reply_count': 0, 'like...
# 2  1563562919207395331  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 3  1563562917106434054  {'retweet_count': 2072, 'reply_count': 0, 'lik...
# 4  1563562916565368833  {'retweet_count': 2, 'reply_count': 0, 'like_c...
#
#    possibly_sensitive  in_reply_to_user_id            author_id  \
# 0                 0.0  1298372735383605249  1555323426784456704
# 1                 0.0                  NaN  1102298694743924737
# 2                 0.0                  NaN   961113187453165569
# 3                 0.0                  NaN  1475050585565057035
# 4                 0.0                  NaN  1474360256016924678
#
#                  created_at reply_settings  geo
# 0  2022-08-27T16:23:44.000Z       everyone  NaN
# 1  2022-08-27T16:23:44.000Z       everyone  NaN
# 2  2022-08-27T16:23:44.000Z       everyone  NaN
# 3  2022-08-27T16:23:43.000Z       everyone  NaN
# 4  2022-08-27T16:23:43.000Z       everyone  NaN

# %% [markdown]
# #### OBTAINING 10000 TWEETS

# %%
# function to get ~10000 tweets

def get_10k():
    
    c = 0

    jsons = []

    while c <= 100:

        if c == 0:
            next_token = None
        else:
            next_token = json_response['meta']['next_token']

        # setting the keywords as a variable
        keywords = '''terror OR alarm OR panic OR unease OR scare OR afraid of OR careful about \ lang:en'''

        # inputs for the request
        bearer_token = auth()
        headers = create_headers(bearer_token)
        keyword = keywords
        max_results = 100

        # getting and printing the response from the API
        url = create_url(keyword, max_results)
        
        json_response = connect_to_endpoint(url[0], headers, url[1], next_token = next_token)
        
        jsons.append(json_response)
        
        c += 1

        time.sleep(5)

    return jsons

# %%
# running function
ten_thousand = get_10k()
# Out:
# Endpoint Response Code: 200
# Endpoint Response Code: 200
# Endpoint Response Code: 200
# Endpoint Response Code: 200
# Endpoint Response Code: 200
# Endpoint Response Code: 200
# Endpoint Response Code: 200
# Endpoint Response Code: 200
# Endpoint Response Code: 200
# Endpoint Response Code: 200
# Endpoint Response Code: 200
# Endpoint Response Code: 200
# Endpoint Response Code: 200
# Endpoint Response Code: 200
# Endpoint Response Code: 200
# Endpoint Response Code: 200
# Endpoint Response Code: 200
# Endpoint Response Code: 200
# Endpoint Response Code: 200
# Endpoint Response Code: 200
# Endpoint Response Code: 200
# Endpoint Response Code: 200
# Endpoint Response Code: 200
# Endpoint Response Code: 200
# Endpoint Response Code: 200
# Endpoint Response Code: 200
# Endpoint Response Code: 200
# Endpoint Response Code: 200
# Endpoint Response Code: 200
# Endpoint Response Code: 200
# Endpoint Response Code: 200
# Endpoint Response Code: 200
# Endpoint Response Code: 200
# Endpoint Response Code: 200
# Endpoint Response Code: 200
# Endpoint Response Code: 200
# Endpoint Response Code: 200
# Endpoint Response Code: 200
# Endpoint Response Code: 200
# Endpoint Response Code: 200
# Endpoint Response Code: 200
# Endpoint Response Code: 200
# Endpoint Response Code: 200
# Endpoint Response Code: 200
# Endpoint Response Code: 200
# Endpoint Response Code: 200
# Endpoint Response Code: 200
# Endpoint Response Code: 200
# Endpoint Response Code: 200
# Endpoint Response Code: 200
# Endpoint Response Code: 200
# Endpoint Response Code: 200
# Endpoint Response Code: 200
# Endpoint Response Code: 200
# Endpoint Response Code: 200
# Endpoint Response Code: 200
# Endpoint Response Code: 200
# Endpoint Response Code: 200
# Endpoint Response Code: 200
# Endpoint Response Code: 200
# Endpoint Response Code: 200
# Endpoint Response Code: 200
# Endpoint Response Code: 200
# Endpoint Response Code: 200
# Endpoint Response Code: 200
# Endpoint Response Code: 200
# Endpoint Response Code: 200
# Endpoint Response Code: 200
# Endpoint Response Code: 200
# Endpoint Response Code: 200
# Endpoint Response Code: 200
# Endpoint Response Code: 200
# Endpoint Response Code: 200
# Endpoint Response Code: 200
# Endpoint Response Code: 200
# Endpoint Response Code: 200
# Endpoint Response Code: 200
# Endpoint Response Code: 200
# Endpoint Response Code: 200
# Endpoint Response Code: 200
# Endpoint Response Code: 200
# Endpoint Response Code: 200
# Endpoint Response Code: 200
# Endpoint Response Code: 200
# Endpoint Response Code: 200
# Endpoint Response Code: 200
# Endpoint Response Code: 200
# Endpoint Response Code: 200
# Endpoint Response Code: 200
# Endpoint Response Code: 200
# Endpoint Response Code: 200
# Endpoint Response Code: 200
# Endpoint Response Code: 200
# Endpoint Response Code: 200
# Endpoint Response Code: 200
# Endpoint Response Code: 200
# Endpoint Response Code: 200
# Endpoint Response Code: 200
# Endpoint Response Code: 200
# Endpoint Response Code: 200
# Endpoint Response Code: 200

# %%
# creating dataframe for the 10 000 tweets
data = pd.DataFrame()

for i in range(0, len(ten_thousand)-1):
  raw_data_ = ten_thousand[i]['data']

  for tweet in raw_data_:
      data = data.append(tweet, ignore_index=True)

#data.drop(['public_metrics'], axis=1, inplace=True)
print(data.shape)
data.head()
# Out:
# (9985, 17)
#                                       public_metrics  \
# 0  {'retweet_count': 4, 'reply_count': 0, 'like_c...
# 1  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 2  {'retweet_count': 3, 'reply_count': 0, 'like_c...
# 3  {'retweet_count': 444, 'reply_count': 0, 'like...
# 4  {'retweet_count': 0, 'reply_count': 0, 'like_c...
#
#                                             entities lang  \
# 0  {'mentions': [{'start': 3, 'end': 14, 'usernam...   en
# 1                                                NaN   en
# 2  {'mentions': [{'start': 3, 'end': 19, 'usernam...   en
# 3  {'mentions': [{'start': 3, 'end': 16, 'usernam...   en
# 4                                                NaN   en
#
#                                                 text      conversation_id  \
# 0  RT @MlkzyHywad: @GOPChairwoman The only cause ...  1563562988434780160
# 1  The true duality of man is living day-to-day i...  1563562986916028419
# 2  RT @musclesnnursing: People keep asking when h...  1563562986765033473
# 3  RT @Logically_JC: If you are afraid of sociali...  1563562986513453061
# 4  what're you doin' tonight, hey, boy?\nset my a...  1563562986182127618
#
#                  created_at  possibly_sensitive            author_id  \
# 0  2022-08-27T16:24:00.000Z                 0.0  1483439745900462091
# 1  2022-08-27T16:24:00.000Z                 0.0            550210137
# 2  2022-08-27T16:24:00.000Z                 0.0             22447783
# 3  2022-08-27T16:24:00.000Z                 0.0  1504505694837522432
# 4  2022-08-27T16:24:00.000Z                 0.0  1531878468882923520
#
#   reply_settings                                context_annotations  \
# 0       everyone  [{'domain': {'id': '10', 'name': 'Person', 'de...
# 1       everyone                                                NaN
# 2       everyone                                                NaN
# 3       everyone                                                NaN
# 4       everyone                                                NaN
#
#                                    referenced_tweets                   source  \
# 0  [{'type': 'retweeted', 'id': '1563551195914186...      Twitter for Android
# 1                                                NaN       Twitter for iPhone
# 2  [{'type': 'retweeted', 'id': '1563329867612954...       Twitter for iPhone
# 3  [{'type': 'retweeted', 'id': '1563522431578361...          Twitter Web App
# 4                                                NaN  Cheap Bots, Done Quick!
#
#                     id in_reply_to_user_id attachments  geo withheld
# 0  1563562988434780160                 NaN         NaN  NaN      NaN
# 1  1563562986916028419                 NaN         NaN  NaN      NaN
# 2  1563562986765033473                 NaN         NaN  NaN      NaN
# 3  1563562986513453061                 NaN         NaN  NaN      NaN
# 4  1563562986182127618                 NaN         NaN  NaN      NaN

# %%
# unpacking the public metrics
df = data.copy()
df = df.public_metrics.dropna().apply(pd.Series)
print(df.shape)
df.head()
# Out:
# (9985, 4)
#    retweet_count  reply_count  like_count  quote_count
# 0              4            0           0            0
# 1              0            0           0            0
# 2              3            0           0            0
# 3            444            0           0            0
# 4              0            0           0            0

# %%
# dropping the dict column 
data_ = data.drop('public_metrics', axis=1)
data_.head()
# Out:
#                                             entities lang  \
# 0  {'mentions': [{'start': 3, 'end': 14, 'usernam...   en
# 1                                                NaN   en
# 2  {'mentions': [{'start': 3, 'end': 19, 'usernam...   en
# 3  {'mentions': [{'start': 3, 'end': 16, 'usernam...   en
# 4                                                NaN   en
#
#                                                 text      conversation_id  \
# 0  RT @MlkzyHywad: @GOPChairwoman The only cause ...  1563562988434780160
# 1  The true duality of man is living day-to-day i...  1563562986916028419
# 2  RT @musclesnnursing: People keep asking when h...  1563562986765033473
# 3  RT @Logically_JC: If you are afraid of sociali...  1563562986513453061
# 4  what're you doin' tonight, hey, boy?\nset my a...  1563562986182127618
#
#                  created_at  possibly_sensitive            author_id  \
# 0  2022-08-27T16:24:00.000Z                 0.0  1483439745900462091
# 1  2022-08-27T16:24:00.000Z                 0.0            550210137
# 2  2022-08-27T16:24:00.000Z                 0.0             22447783
# 3  2022-08-27T16:24:00.000Z                 0.0  1504505694837522432
# 4  2022-08-27T16:24:00.000Z                 0.0  1531878468882923520
#
#   reply_settings                                context_annotations  \
# 0       everyone  [{'domain': {'id': '10', 'name': 'Person', 'de...
# 1       everyone                                                NaN
# 2       everyone                                                NaN
# 3       everyone                                                NaN
# 4       everyone                                                NaN
#
#                                    referenced_tweets                   source  \
# 0  [{'type': 'retweeted', 'id': '1563551195914186...      Twitter for Android
# 1                                                NaN       Twitter for iPhone
# 2  [{'type': 'retweeted', 'id': '1563329867612954...       Twitter for iPhone
# 3  [{'type': 'retweeted', 'id': '1563522431578361...          Twitter Web App
# 4                                                NaN  Cheap Bots, Done Quick!
#
#                     id in_reply_to_user_id attachments  geo withheld
# 0  1563562988434780160                 NaN         NaN  NaN      NaN
# 1  1563562986916028419                 NaN         NaN  NaN      NaN
# 2  1563562986765033473                 NaN         NaN  NaN      NaN
# 3  1563562986513453061                 NaN         NaN  NaN      NaN
# 4  1563562986182127618                 NaN         NaN  NaN      NaN

# %%
# creating the final dataframe that will be used fot EDA and ML
final_df = pd.concat([data_, df], axis=1)
print(final_df.shape)
final_df.head()
# Out:
# (9985, 20)
#                                             entities lang  \
# 0  {'mentions': [{'start': 3, 'end': 14, 'usernam...   en
# 1                                                NaN   en
# 2  {'mentions': [{'start': 3, 'end': 19, 'usernam...   en
# 3  {'mentions': [{'start': 3, 'end': 16, 'usernam...   en
# 4                                                NaN   en
#
#                                                 text      conversation_id  \
# 0  RT @MlkzyHywad: @GOPChairwoman The only cause ...  1563562988434780160
# 1  The true duality of man is living day-to-day i...  1563562986916028419
# 2  RT @musclesnnursing: People keep asking when h...  1563562986765033473
# 3  RT @Logically_JC: If you are afraid of sociali...  1563562986513453061
# 4  what're you doin' tonight, hey, boy?\nset my a...  1563562986182127618
#
#                  created_at  possibly_sensitive            author_id  \
# 0  2022-08-27T16:24:00.000Z                 0.0  1483439745900462091
# 1  2022-08-27T16:24:00.000Z                 0.0            550210137
# 2  2022-08-27T16:24:00.000Z                 0.0             22447783
# 3  2022-08-27T16:24:00.000Z                 0.0  1504505694837522432
# 4  2022-08-27T16:24:00.000Z                 0.0  1531878468882923520
#
#   reply_settings                                context_annotations  \
# 0       everyone  [{'domain': {'id': '10', 'name': 'Person', 'de...
# 1       everyone                                                NaN
# 2       everyone                                                NaN
# 3       everyone                                                NaN
# 4       everyone                                                NaN
#
#                                    referenced_tweets                   source  \
# 0  [{'type': 'retweeted', 'id': '1563551195914186...      Twitter for Android
# 1                                                NaN       Twitter for iPhone
# 2  [{'type': 'retweeted', 'id': '1563329867612954...       Twitter for iPhone
# 3  [{'type': 'retweeted', 'id': '1563522431578361...          Twitter Web App
# 4                                                NaN  Cheap Bots, Done Quick!
#
#                     id in_reply_to_user_id attachments  geo withheld  \
# 0  1563562988434780160                 NaN         NaN  NaN      NaN
# 1  1563562986916028419                 NaN         NaN  NaN      NaN
# 2  1563562986765033473                 NaN         NaN  NaN      NaN
# 3  1563562986513453061                 NaN         NaN  NaN      NaN
# 4  1563562986182127618                 NaN         NaN  NaN      NaN
#
#    retweet_count  reply_count  like_count  quote_count
# 0              4            0           0            0
# 1              0            0           0            0
# 2              3            0           0            0
# 3            444            0           0            0
# 4              0            0           0            0

# %%
# saving the data in a csv file
final_df.to_csv('C:/Users/camil/Documents/Courses/Projects/NLP/twitter_fear_sentiment_analysis/final_df.csv', sep=",", header=True, index=False)
